# %%
"""
In this notebook we compare performance of the various preprocessing routines on the dataset
with 12k cases from Illinois with decision date after 1950.
"""

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

results_header = '/Users/jhamer90811/Documents/Insight/legal_topic_modeling/validation_output'

preprocessor_headers = ['baseline', 'basic_stopwords', 'phrasing', 'phrasing_basic_stopwords',
                       'basic_stopwords_nouns']

dataset = 'cases_IL_after1950_12k'

# %%
data = pd.DataFrame()
for prep in preprocessor_headers:
    new_data = pd.read_csv(os.path.join(results_header, prep + '_12k', dataset + '.csv'))
    new_data['preprocessor'] = prep
    data = data.append(new_data, ignore_index=True)

# %%
data
# Out:
#     num_topics  train_perplexity  test_perplexity  train_coherence  \
# 0            5        160.986002       174.132400         0.394392
# 1            8        157.532171       174.233645         0.365319
# 2           10        154.563544       173.036657         0.409554
# 3           12        155.490866       176.936117         0.395248
# 4           15        154.798267       178.970866         0.395696
# 5            5        189.686968       207.150330         0.438655
# 6            8        183.476754       205.546648         0.462469
# 7           10        181.741267       206.368661         0.459582
# 8           12        179.245172       206.919620         0.462537
# 9           15        180.932729       213.513497         0.451660
# 10           5        164.795750       179.507105         0.356479
# 11           8        160.660210       179.693753         0.376878
# 12          10        158.832952       180.431289         0.385826
# 13          12        158.817996       183.022843         0.408178
# 14          15        156.900058       184.112349         0.385021
# 15           5        190.763980       210.342589         0.446946
# 16           8        188.320229       213.561094         0.435393
# 17          10        184.490609       212.161885         0.460545
# 18          12        183.935250       216.006157         0.468795
# 19          15        182.819133       219.474977         0.466234
# 20           5        119.238844       132.358071         0.441431
# 21           8        115.652562       131.870661         0.432353
# 22          10        114.756515       132.618366         0.444466
# 23          12        112.994123       132.515971         0.445099
# 24          15        110.570703       133.081635         0.486658
#
#     test_coherence  min_cite_dist_mean  min_cite_dist_sd  avg_cite_dist_mean  \
# 0         0.398647            4.165899          1.007163            5.144952
# 1         0.367333            4.082530          1.044031            5.075241
# 2         0.408867            4.034772          1.075155            5.044240
# 3         0.396238            4.012987          1.061913            5.028069
# 4         0.396388            4.016757          1.078893            5.025052
# 5         0.438940            4.176372          1.003086            5.154755
# 6         0.462907            4.055718          1.038567            5.069795
# 7         0.458081            4.063259          1.069553            5.069962
# 8         0.460490            4.029326          1.070434            5.043653
# 9         0.448195            4.029326          1.061390            5.031504
# 10        0.358838            4.162128          1.012548            5.147633
# 11        0.378549            4.122748          1.034411            5.103310
# 12        0.387286            4.080855          1.015264            5.060494
# 13        0.407868            4.022623          1.076453            5.035274
# 14        0.385903            3.952241          1.106741            4.979556
# 15        0.443260            4.161290          1.001446            5.123586
# 16        0.434018            4.074152          1.049463            5.104902
# 17        0.457176            4.074152          1.039834            5.054378
# 18        0.465687            4.040637          1.078063            5.029409
# 19        0.460484            3.955174          1.093340            4.992208
# 20        0.439453            4.193129          1.010831            5.150901
# 21        0.432070            4.079179          1.047896            5.078090
# 22        0.445152            4.047340          1.048619            5.059321
# 23        0.447044            4.033934          1.060265            5.036783
# 24        0.483958            4.009217          1.091343            5.028069
#
#     avg_cite_dist_sd  max_cite_dist_mean  max_cite_dist_sd  \
# 0           0.807054            6.199413          1.030767
# 1           0.834123            6.125681          1.048348
# 2           0.827231            6.117302          1.035650
# 3           0.816756            6.118140          1.040803
# 4           0.838747            6.096774          1.019229
# 5           0.816981            6.198157          1.023871
# 6           0.822038            6.136154          1.044835
# 7           0.832159            6.135735          1.050690
# 8           0.824776            6.124424          1.030557
# 9           0.822247            6.107248          1.034312
# 10          0.806089            6.201089          1.013628
# 11          0.815463            6.148722          1.013365
# 12          0.803196            6.103058          0.999297
# 13          0.841473            6.077084          1.033759
# 14          0.864917            6.024298          1.063884
# 15          0.795287            6.144114          0.997991
# 16          0.805423            6.186845          1.003487
# 17          0.814090            6.118978          1.026516
# 18          0.829419            6.069543          1.043572
# 19          0.831256            6.061584          1.053463
# 20          0.815711            6.182237          1.031305
# 21          0.810432            6.155425          1.026337
# 22          0.815401            6.136573          1.016518
# 23          0.825924            6.105991          1.028550
# 24          0.827503            6.120235          1.055956
#
#                 preprocessor
# 0                   baseline
# 1                   baseline
# 2                   baseline
# 3                   baseline
# 4                   baseline
# 5            basic_stopwords
# 6            basic_stopwords
# 7            basic_stopwords
# 8            basic_stopwords
# 9            basic_stopwords
# 10                  phrasing
# 11                  phrasing
# 12                  phrasing
# 13                  phrasing
# 14                  phrasing
# 15  phrasing_basic_stopwords
# 16  phrasing_basic_stopwords
# 17  phrasing_basic_stopwords
# 18  phrasing_basic_stopwords
# 19  phrasing_basic_stopwords
# 20     basic_stopwords_nouns
# 21     basic_stopwords_nouns
# 22     basic_stopwords_nouns
# 23     basic_stopwords_nouns
# 24     basic_stopwords_nouns

# %%
# Train perplexity
ax = sns.lineplot('num_topics', 'train_perplexity', hue='preprocessor', data=data)
ax.set_title('Train Perplexity vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Test perplexity
ax = sns.lineplot('num_topics', 'test_perplexity', hue='preprocessor', data=data)
ax.set_title('Test Perplexity vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Train coherence
ax = sns.lineplot('num_topics', 'train_coherence', hue='preprocessor', data=data)
ax.set_title('Train Coherence vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Test coherence
ax = sns.lineplot('num_topics', 'test_coherence', hue='preprocessor', data=data)
ax.set_title('Test Coherence vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance
ax = sns.lineplot('num_topics', 'min_cite_dist_mean', hue='preprocessor', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance
ax = sns.lineplot('num_topics', 'avg_cite_dist_mean', hue='preprocessor', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance
ax = sns.lineplot('num_topics', 'max_cite_dist_mean', hue='preprocessor', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance sd
ax = sns.lineplot('num_topics', 'min_cite_dist_sd', hue='preprocessor', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance sd
ax = sns.lineplot('num_topics', 'avg_cite_dist_sd', hue='preprocessor', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance sd
ax = sns.lineplot('num_topics', 'max_cite_dist_sd', hue='preprocessor', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Use if stdev bars are desired

def plot_with_error_bars(df, x, y, y_err, group_by):
    groups = df.groupby(group_by)[[x, y, y_err]]

    fig, ax = plt.subplots()

    for k, v in groups:
        v.plot(label=k, x=x, y=y, ax=ax)
        plt.fill_between(v[x], v[y]-v[y_err], v[y]+v[y_err], alpha=0.1)

    ax.legend()
    ax.set_title(f'{y} vs. {x}; by {group_by}')

    plt.show()

# %%
# Min citation distance
plot_with_error_bars(data, 'num_topics', 'min_cite_dist_mean', 'min_cite_dist_sd', 'name')

# %%
# Average citation distance
plot_with_error_bars(data, 'num_topics', 'avg_cite_dist_mean', 'avg_cite_dist_sd', 'name')

# %%
# Maximum citation distance
plot_with_error_bars(data, 'num_topics', 'max_cite_dist_mean', 'max_cite_dist_sd', 'name')
