# %%
"""
In this notebook we compare performance topic modeling for the basic_stopwords and 
basic_stopwords_nouns preprocessors for the different sample sizes 12k and 42k. We restrict
to the cases_IL_after1950 datasets.
"""

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

results_header = '/Users/jhamer90811/Documents/Insight/legal_topic_modeling/validation_output'

preprocessor_headers = ['basic_stopwords', 'basic_stopwords_nouns']

sizes = ['_12k', '_42k']

dataset = 'cases_IL_after1950'

# %%
data = pd.DataFrame()
for prep in preprocessor_headers:
    for size in sizes:
        new_data = pd.read_csv(os.path.join(results_header, prep + size, dataset + size + '.csv'))
        new_data['name'] = prep+size
        data = data.append(new_data, ignore_index=True)
# Out:
# /Applications/anaconda3/envs/insight/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
data
# Out:
#     avg_cite_dist_mean  avg_cite_dist_sd  max_cite_dist_mean  \
# 0             5.154755          0.816981            6.198157
# 1             5.069795          0.822038            6.136154
# 2             5.069962          0.832159            6.135735
# 3             5.043653          0.824776            6.124424
# 4             5.031504          0.822247            6.107248
# 5             5.164045          0.834723            6.237328
# 6             5.093771          0.836366            6.168167
# 7             5.058835          0.838676            6.144363
# 8             5.028351          0.855172            6.104216
# 9             4.977523          0.882124            6.070583
# 10            5.150901          0.815711            6.182237
# 11            5.078090          0.810432            6.155425
# 12            5.059321          0.815401            6.136573
# 13            5.036783          0.825924            6.105991
# ...

# %%
# Test perplexity
ax = sns.lineplot('num_topics', 'test_perplexity', hue='name', data=data)
ax.set_title('Test Perplexity vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()

# %%
# Test coherence
ax = sns.lineplot('num_topics', 'test_coherence', hue='name', data=data)
ax.set_title('Test Coherence vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()

# %%
# Min citation distance
ax = sns.lineplot('num_topics', 'min_cite_dist_mean', hue='name', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()

# %%
# Average citation distance
ax = sns.lineplot('num_topics', 'avg_cite_dist_mean', hue='name', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()

# %%
# Maximum citation distance
ax = sns.lineplot('num_topics', 'max_cite_dist_mean', hue='name', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()

# %%
# Min citation distance sd
ax = sns.lineplot('num_topics', 'min_cite_dist_sd', hue='name', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()

# %%
# Average citation distance sd
ax = sns.lineplot('num_topics', 'avg_cite_dist_sd', hue='name', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()

# %%
# Maximum citation distance sd
ax = sns.lineplot('num_topics', 'max_cite_dist_sd', hue='name', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
ax.legend(title='Preprocessor')
plt.show()
