# %%
"""
In this notebook we compare performance of topic modeling for the basic_stopwords_nouns
preprocessor and the different sample sizes 12k and 42k. We restrict
to the cases_IL_after1950 datasets.
"""

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

results_header = '/Users/jhamer90811/Documents/Insight/legal_topic_modeling/validation_output'

preprocessor_headers = ['basic_stopwords_nouns']

sizes = ['_12k', '_42k']

dataset = 'cases_IL_after1950'

# %%
data = pd.DataFrame()
for prep in preprocessor_headers:
    for size in sizes:
        new_data = pd.read_csv(os.path.join(results_header, prep + size, dataset + size + '.csv'))
        new_data['preprocessor_size'] = prep+size
        data = data.append(new_data, ignore_index=True)
# Out:
# /Applications/anaconda3/envs/insight/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
data
# Out:
#    avg_cite_dist_mean  avg_cite_dist_sd  max_cite_dist_mean  max_cite_dist_sd  \
# 0            5.150901          0.815711            6.182237          1.031305
# 1            5.078090          0.810432            6.155425          1.026337
# 2            5.059321          0.815401            6.136573          1.016518
# 3            5.036783          0.825924            6.105991          1.028550
# 4            5.028069          0.827503            6.120235          1.055956
# 5            5.173093          0.820792            6.228328          1.036226
# 6            5.139247          0.829144            6.220630          1.036007
# 7            5.083847          0.851599            6.173851          1.072896
# 8            5.035552          0.850876            6.128612          1.052249
# 9            4.999905          0.871679            6.105992          1.066549
#
#    min_cite_dist_mean  min_cite_dist_sd  num_topics  \
# 0            4.193129          1.010831           5
# 1            4.079179          1.047896           8
# 2            4.047340          1.048619          10
# 3            4.033934          1.060265          12
# 4            4.009217          1.091343          15
# 5            4.177759          1.028562           5
# 6            4.111203          1.057316           8
# 7            4.027001          1.104074          10
# 8            3.949550          1.124096          12
# 9            3.912364          1.168558          15
#
#            preprocessor_size  test_coherence  test_perplexity  \
# 0  basic_stopwords_nouns_12k        0.439453       132.358071
# 1  basic_stopwords_nouns_12k        0.432070       131.870661
# 2  basic_stopwords_nouns_12k        0.445152       132.618366
# 3  basic_stopwords_nouns_12k        0.447044       132.515971
# 4  basic_stopwords_nouns_12k        0.483958       133.081635
# 5  basic_stopwords_nouns_42k        0.452499       120.673958
# 6  basic_stopwords_nouns_42k        0.521136       117.750370
# 7  basic_stopwords_nouns_42k        0.483520       116.643787
# 8  basic_stopwords_nouns_42k        0.478570       114.317166
# 9  basic_stopwords_nouns_42k        0.491268       112.530275
#
#    train_coherence  train_perplexity
# 0         0.441431        119.238844
# 1         0.432353        115.652562
# 2         0.444466        114.756515
# 3         0.445099        112.994123
# 4         0.486658        110.570703
# 5              NaN               NaN
# 6              NaN               NaN
# 7              NaN               NaN
# 8              NaN               NaN
# 9              NaN               NaN

# %%
# Test perplexity
ax = sns.lineplot('num_topics', 'test_perplexity', hue='preprocessor_size', data=data)
ax.set_title('Test Perplexity vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Test coherence
ax = sns.lineplot('num_topics', 'test_coherence', hue='preprocessor_size', data=data)
ax.set_title('Test Coherence vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance
ax = sns.lineplot('num_topics', 'min_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance
ax = sns.lineplot('num_topics', 'avg_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance
ax = sns.lineplot('num_topics', 'max_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance sd
ax = sns.lineplot('num_topics', 'min_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance sd
ax = sns.lineplot('num_topics', 'avg_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance sd
ax = sns.lineplot('num_topics', 'max_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
