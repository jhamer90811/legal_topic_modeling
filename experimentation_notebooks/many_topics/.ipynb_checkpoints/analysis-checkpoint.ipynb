# %%
"""
In this notebook we compare performance of topic modeling for the basic_stopwords_nouns_verbs
preprocessor and the different sample sizes 12k and 42k. We restrict
to the cases_IL_after1950 datasets.
"""

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

results_header = '/Users/jhamer90811/Documents/Insight/legal_topic_modeling/validation_output'

preprocessor_headers = ['basic_stopwords', 'basic_stopwords_nouns_verbs']

sizes = ['_12k', '_42k']

num_topics = ['', '_many_topics']

dataset = 'cases_IL_after1950'

# %%
data = pd.DataFrame()
for prep in preprocessor_headers:
    for size in sizes:
        for nt in num_topics:
            new_data = pd.read_csv(os.path.join(results_header, prep + size, dataset + size + nt+ '.csv'))
            new_data['preprocessor_size'] = prep+size
            data = data.append(new_data, ignore_index=True)
# Out:
# /Applications/anaconda3/envs/insight/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
data
# Out:
#     avg_cite_dist_mean  avg_cite_dist_sd  max_cite_dist_mean  \
# 0             5.154755          0.816981            6.198157
# 1             5.069795          0.822038            6.136154
# 2             5.069962          0.832159            6.135735
# 3             5.043653          0.824776            6.124424
# 4             5.031504          0.822247            6.107248
# 5             4.973439          0.829556            6.034772
# 6             4.848345          0.863505            5.917051
# 7             4.888395          0.857458            5.992459
# 8             4.851864          0.866828            5.940092
# 9             5.164045          0.834723            6.237328
# 10            5.093771          0.836366            6.168167
# 11            5.058835          0.838676            6.144363
# 12            5.028351          0.855172            6.104216
# 13            4.977523          0.882124            6.070583
# 14            4.899905          0.897850            6.018830
# 15            4.795571          0.928307            5.941023
# 16            4.756135          0.933328            5.905140
# 17            4.727594          0.945449            5.868664
# 18                 NaN               NaN                 NaN
# 19                 NaN               NaN                 NaN
# 20                 NaN               NaN                 NaN
# 21                 NaN               NaN                 NaN
# 22                 NaN               NaN                 NaN
# 23                 NaN               NaN                 NaN
# 24                 NaN               NaN                 NaN
# 25                 NaN               NaN                 NaN
# 26                 NaN               NaN                 NaN
# 27                 NaN               NaN                 NaN
# 28                 NaN               NaN                 NaN
# 29                 NaN               NaN                 NaN
# 30                 NaN               NaN                 NaN
# 31                 NaN               NaN                 NaN
# 32                 NaN               NaN                 NaN
# 33                 NaN               NaN                 NaN
# 34                 NaN               NaN                 NaN
# 35                 NaN               NaN                 NaN
#
#     max_cite_dist_sd  min_cite_dist_mean  min_cite_dist_sd  num_topics  \
# 0           1.023871            4.176372          1.003086           5
# 1           1.044835            4.055718          1.038567           8
# 2           1.050690            4.063259          1.069553          10
# 3           1.030557            4.029326          1.070434          12
# 4           1.034312            4.029326          1.061390          15
# 5           1.002117            3.927943          1.119739          25
# 6           1.040983            3.802262          1.154943          50
# 7           1.056625            3.815668          1.124835          75
# 8           1.088004            3.762044          1.150611         100
# 9           1.051465            4.165561          1.042536           5
# 10          1.054996            4.062766          1.073886           8
# 11          1.041540            3.999882          1.125280          10
# 12          1.064334            3.986026          1.114458          12
# 13          1.095031            3.890455          1.178475          15
# 14          1.078249            3.771080          1.226870          25
# 15          1.118081            3.639626          1.258602          50
# 16          1.109488            3.574254          1.280529          75
# 17          1.122981            3.550095          1.288522         100
# 18               NaN                 NaN               NaN           5
# 19               NaN                 NaN               NaN           8
# 20               NaN                 NaN               NaN          10
# 21               NaN                 NaN               NaN          12
# 22               NaN                 NaN               NaN          15
# 23               NaN                 NaN               NaN          25
# 24               NaN                 NaN               NaN          50
# 25               NaN                 NaN               NaN          75
# 26               NaN                 NaN               NaN         100
# 27               NaN                 NaN               NaN           5
# 28               NaN                 NaN               NaN           8
# 29               NaN                 NaN               NaN          10
# 30               NaN                 NaN               NaN          12
# 31               NaN                 NaN               NaN          15
# 32               NaN                 NaN               NaN          25
# 33               NaN                 NaN               NaN          50
# 34               NaN                 NaN               NaN          75
# 35               NaN                 NaN               NaN         100
#
#                   preprocessor_size  test_coherence  test_perplexity  \
# 0               basic_stopwords_12k        0.438940       207.150330
# 1               basic_stopwords_12k        0.462907       205.546648
# 2               basic_stopwords_12k        0.458081       206.368661
# 3               basic_stopwords_12k        0.460490       206.919620
# 4               basic_stopwords_12k        0.448195       213.513497
# 5               basic_stopwords_12k        0.459039       223.123110
# 6               basic_stopwords_12k             NaN       252.517805
# 7               basic_stopwords_12k             NaN       295.251459
# 8               basic_stopwords_12k             NaN       409.449879
# 9               basic_stopwords_42k        0.483920       189.921089
# 10              basic_stopwords_42k        0.494194       184.964478
# 11              basic_stopwords_42k        0.480418       184.670824
# 12              basic_stopwords_42k        0.498855       182.288170
# 13              basic_stopwords_42k        0.518922       180.717316
# 14              basic_stopwords_42k        0.537772       177.940708
# 15              basic_stopwords_42k             NaN       179.229607
# 16              basic_stopwords_42k             NaN       194.066610
# 17              basic_stopwords_42k             NaN       270.252435
# 18  basic_stopwords_nouns_verbs_12k        0.468575       161.302279
# 19  basic_stopwords_nouns_verbs_12k        0.470815       159.994239
# 20  basic_stopwords_nouns_verbs_12k        0.458175       158.455119
# 21  basic_stopwords_nouns_verbs_12k        0.456474       159.752165
# 22  basic_stopwords_nouns_verbs_12k        0.455803       161.071652
# 23  basic_stopwords_nouns_verbs_12k        0.446610       166.878338
# 24  basic_stopwords_nouns_verbs_12k             NaN       186.448810
# 25  basic_stopwords_nouns_verbs_12k             NaN       216.484436
# 26  basic_stopwords_nouns_verbs_12k             NaN       290.353102
# 27  basic_stopwords_nouns_verbs_42k        0.452949       148.298540
# 28  basic_stopwords_nouns_verbs_42k        0.459318       143.079481
# 29  basic_stopwords_nouns_verbs_42k        0.505337       144.141923
# 30  basic_stopwords_nouns_verbs_42k        0.512057       140.663541
# 31  basic_stopwords_nouns_verbs_42k        0.520374       138.786661
# 32  basic_stopwords_nouns_verbs_42k        0.525074       137.269522
# 33  basic_stopwords_nouns_verbs_42k        0.531428       135.654789
# 34  basic_stopwords_nouns_verbs_42k        0.524552       144.952609
# 35  basic_stopwords_nouns_verbs_42k             NaN       197.760569
#
#     train_coherence  train_perplexity
# 0          0.438655        189.686968
# 1          0.462469        183.476754
# 2          0.459582        181.741267
# 3          0.462537        179.245172
# 4          0.451660        180.932729
# 5               NaN               NaN
# 6               NaN               NaN
# 7               NaN               NaN
# 8               NaN               NaN
# 9               NaN               NaN
# 10              NaN               NaN
# 11              NaN               NaN
# 12              NaN               NaN
# 13              NaN               NaN
# 14              NaN               NaN
# 15              NaN               NaN
# 16              NaN               NaN
# 17              NaN               NaN
# 18              NaN               NaN
# 19              NaN               NaN
# 20              NaN               NaN
# 21              NaN               NaN
# 22              NaN               NaN
# 23              NaN               NaN
# 24              NaN               NaN
# 25              NaN               NaN
# 26              NaN               NaN
# 27              NaN               NaN
# 28              NaN               NaN
# 29              NaN               NaN
# 30              NaN               NaN
# 31              NaN               NaN
# 32              NaN               NaN
# 33              NaN               NaN
# 34              NaN               NaN
# 35              NaN               NaN

# %%
# Test perplexity
ax = sns.lineplot('num_topics', 'test_perplexity', hue='preprocessor_size', data=data)
ax.set_title('Test Perplexity vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Test coherence
ax = sns.lineplot('num_topics', 'test_coherence', hue='preprocessor_size', data=data)
ax.set_title('Test Coherence vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance
ax = sns.lineplot('num_topics', 'min_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance
ax = sns.lineplot('num_topics', 'avg_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance
ax = sns.lineplot('num_topics', 'max_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance sd
ax = sns.lineplot('num_topics', 'min_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance sd
ax = sns.lineplot('num_topics', 'avg_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance sd
ax = sns.lineplot('num_topics', 'max_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Now compare preprocessors, with 42k dataset

preprocessor_headers = ['basic_stopwords_nouns', 'basic_stopwords_nouns_verbs']

sizes = ['_42k']

num_topics = ['']

dataset = 'cases_IL_after1950'

# %%
data = pd.DataFrame()
for prep in preprocessor_headers:
    for size in sizes:
        for nt in num_topics:
            new_data = pd.read_csv(os.path.join(results_header, prep + size, dataset + size + nt+ '.csv'))
            new_data['preprocessor_size'] = prep+size
            data = data.append(new_data, ignore_index=True)

# %%
data
# Out:
#    avg_cite_dist_mean  avg_cite_dist_sd  max_cite_dist_mean  max_cite_dist_sd  \
# 0            5.173093          0.820792            6.228328          1.036226
# 1            5.139247          0.829144            6.220630          1.036007
# 2            5.083847          0.851599            6.173851          1.072896
# 3            5.035552          0.850876            6.128612          1.052249
# 4            4.999905          0.871679            6.105992          1.066549
# 5                 NaN               NaN                 NaN               NaN
# 6                 NaN               NaN                 NaN               NaN
# 7                 NaN               NaN                 NaN               NaN
# 8                 NaN               NaN                 NaN               NaN
# 9                 NaN               NaN                 NaN               NaN
#
#    min_cite_dist_mean  min_cite_dist_sd  num_topics  \
# 0            4.177759          1.028562           5
# 1            4.111203          1.057316           8
# 2            4.027001          1.104074          10
# 3            3.949550          1.124096          12
# 4            3.912364          1.168558          15
# 5                 NaN               NaN           5
# 6                 NaN               NaN           8
# 7                 NaN               NaN          10
# 8                 NaN               NaN          12
# 9                 NaN               NaN          15
#
#                  preprocessor_size  test_coherence  test_perplexity
# 0        basic_stopwords_nouns_42k        0.452499       120.673958
# 1        basic_stopwords_nouns_42k        0.521136       117.750370
# 2        basic_stopwords_nouns_42k        0.483520       116.643787
# 3        basic_stopwords_nouns_42k        0.478570       114.317166
# 4        basic_stopwords_nouns_42k        0.491268       112.530275
# 5  basic_stopwords_nouns_verbs_42k        0.452949       148.298540
# 6  basic_stopwords_nouns_verbs_42k        0.459318       143.079481
# 7  basic_stopwords_nouns_verbs_42k        0.505337       144.141923
# 8  basic_stopwords_nouns_verbs_42k        0.512057       140.663541
# 9  basic_stopwords_nouns_verbs_42k        0.520374       138.786661

# %%
# Test perplexity
ax = sns.lineplot('num_topics', 'test_perplexity', hue='preprocessor_size', data=data)
ax.set_title('Test Perplexity vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Test coherence
ax = sns.lineplot('num_topics', 'test_coherence', hue='preprocessor_size', data=data)
ax.set_title('Test Coherence vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance
ax = sns.lineplot('num_topics', 'min_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance
ax = sns.lineplot('num_topics', 'avg_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance
ax = sns.lineplot('num_topics', 'max_cite_dist_mean', hue='preprocessor_size', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Min citation distance sd
ax = sns.lineplot('num_topics', 'min_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Min Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Average citation distance sd
ax = sns.lineplot('num_topics', 'avg_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Avg Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# Maximum citation distance sd
ax = sns.lineplot('num_topics', 'max_cite_dist_sd', hue='preprocessor_size', data=data)
ax.set_title('Max Citation Distance vs. Number of Topics')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
